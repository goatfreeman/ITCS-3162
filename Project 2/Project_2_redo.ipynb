# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
loan = pd.read_csv('/content/drive/MyDrive/2024 - Fall/ITCS - 3162/loan.csv')
loan
# Out:
#     age  gender    occupation education_level marital_status  income  \
# 0    32    Male      Engineer      Bachelor's        Married   85000
# 1    45  Female       Teacher        Master's         Single   62000
# 2    28    Male       Student     High School         Single   25000
# 3    51  Female       Manager      Bachelor's        Married  105000
# 4    36    Male    Accountant      Bachelor's        Married   75000
# ..  ...     ...           ...             ...            ...     ...
# 56   39    Male     Architect        Master's        Married  100000
# 57   25  Female  Receptionist     High School         Single   32000
# 58   43    Male        Banker      Bachelor's        Married   95000
# 59   30  Female        Writer        Master's         Single   55000
# 60   38    Male          Chef     Associate's        Married   65000
#
#     credit_score loan_status
# 0            720    Approved
# 1            680    Approved
# 2            590      Denied
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['loan_status'].value_counts()
    for x_label, grp in _df_21.groupby('marital_status')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('marital_status')
_ = plt.ylabel('loan_status')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_5.groupby('education_level').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_4.groupby('gender').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
loan.columns
# Out:
# Index(['age', 'gender', 'occupation', 'education_level', 'marital_status',
#        'income', 'credit_score', 'loan_status'],
#       dtype='object')

# %%
loan.isna().sum()
# Out:
# age                0
# gender             0
# occupation         0
# education_level    0
# marital_status     0
# income             0
# credit_score       0
# loan_status        0
# dtype: int64

# %%
sns.countplot(x="loan_status",data = loan)
# Out:
# <Axes: xlabel='loan_status', ylabel='count'>

# %%
fig, ax = plt.subplots(figsize=(20, 10))
sns.countplot(x='credit_score',hue='loan_status',data = loan)
# Out:
# <Axes: xlabel='credit_score', ylabel='count'>

# %%
loan.dtypes
# Out:
# age                 int64
# gender             object
# occupation         object
# education_level    object
# marital_status     object
# income              int64
# credit_score        int64
# loan_status        object
# dtype: object

# %%
loan['education_level'].value_counts()
# Out:
# education_level
# Bachelor's     23
# Master's       15
# Doctoral       10
# High School     7
# Associate's     6
# Name: count, dtype: int64

# %%
cols = list(loan.columns)
cols.remove('loan_status')
loan = pd.get_dummies(loan, columns=cols)

# %%
loan
# Out:
#    loan_status  age_24  age_25  age_26  age_27  age_28  age_29  age_30  \
# 0     Approved   False   False   False   False   False   False   False
# 1     Approved   False   False   False   False   False   False   False
# 2       Denied   False   False   False   False    True   False   False
# 3     Approved   False   False   False   False   False   False   False
# 4     Approved   False   False   False   False   False   False   False
# ..         ...     ...     ...     ...     ...     ...     ...     ...
# 56    Approved   False   False   False   False   False   False   False
# 57      Denied   False    True   False   False   False   False   False
# 58    Approved   False   False   False   False   False   False   False
# 59    Approved   False   False   False   False   False   False    True
# 60    Approved   False   False   False   False   False   False   False
#
#     age_31  age_32  ...  credit_score_740  credit_score_750  credit_score_760  \
# ...

# %%
X = loan.drop(columns = ['loan_status'])
y = loan['loan_status']

# %%
X
# Out:
#     age_24  age_25  age_26  age_27  age_28  age_29  age_30  age_31  age_32  \
# 0    False   False   False   False   False   False   False   False    True
# 1    False   False   False   False   False   False   False   False   False
# 2    False   False   False   False    True   False   False   False   False
# 3    False   False   False   False   False   False   False   False   False
# 4    False   False   False   False   False   False   False   False   False
# ..     ...     ...     ...     ...     ...     ...     ...     ...     ...
# 56   False   False   False   False   False   False   False   False   False
# 57   False    True   False   False   False   False   False   False   False
# 58   False   False   False   False   False   False   False   False   False
# 59   False   False   False   False   False   False    True   False   False
# 60   False   False   False   False   False   False   False   False   False
#
# ...

# %%
y
# Out:
# 0     Approved
# 1     Approved
# 2       Denied
# 3     Approved
# 4     Approved
#         ...
# 56    Approved
# 57      Denied
# 58    Approved
# 59    Approved
# 60    Approved
# Name: loan_status, Length: 61, dtype: object

# %%
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.5)

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((30, 147), (30,), (31, 147), (31,))

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)

# %%
clf.score(X_test, y_test)
# Out:
# 0.967741935483871

# %%
fig, axes = plt.subplots(nrows = 1,ncols = 1, figsize = (48,34), dpi=300)
tree.plot_tree(clf, max_depth = None, feature_names = X.columns, filled=True)
plt.show()

# %%
from sklearn import metrics

# %%
predicted = clf.predict(X_test)

# %%
print(metrics.classification_report(y_test, predicted))
# Out:
#               precision    recall  f1-score   support
#
#     Approved       1.00      0.95      0.97        20
#       Denied       0.92      1.00      0.96        11
#
#     accuracy                           0.97        31
#    macro avg       0.96      0.97      0.97        31
# weighted avg       0.97      0.97      0.97        31

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
confusion_matrix(y_test, predicted)
# Out:
# array([[19,  1],
#        [ 0, 11]])

# %%
cm = confusion_matrix(y_test, predicted)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=['Predicted 0', 'Predicted 1'],
            yticklabels=['Actual 0', 'Actual 1'])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix for Loan Approval")
plt.show()
